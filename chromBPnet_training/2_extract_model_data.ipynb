# %%
# Average the bias factorized models across foldsto generate a single merged model.
# Bias factor = 1.0

# %% [markdown]
# These cells are dedicated to extracting the predictions and contribution scores (bigwig files) across folds. These data are used by the motif discovery programs downstream from ChromBPnet

# %%
import os
bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/chromBPnet_training/bash"

# !sbatch $bash/generate_contribution_scores.sh # takes a long time
# !sbatch $bash/generate_prediction_scores.sh # runs fast
# Out:
# Submitted batch job 22250953
# Submitted batch job 22250954

# %%
import os
bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/chromBPnet_training/bash"

# !sbatch $bash/average_extracted_scores.sh
# Out:
# Submitted batch job 22251042

# %%
# Average the contribution counts scores across folds to generate a single merged model.

file_pattern = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/chromBPnet_training/outputs/pbmc_merged/chrombpnet_model_b1.0/contribution_scores_bw/fold_*/pbmc-merged.counts_scores.h5"
output_path = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/chromBPnet_training/outputs/pbmc_merged/chrombpnet_model_b1.0/contribution_scores_bw/averaged_scores/averaged_folds_pbmc-merged.counts_scores.h5"
# !sbatch $bash/average_contribution_scores_h5.sh $file_pattern $output_path

# Average the contribution profile scores across folds to generate a single merged model.

file_pattern = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/chromBPnet_training/outputs/pbmc_merged/chrombpnet_model_b1.0/contribution_scores_bw/fold_*/pbmc-merged.profile_scores.h5"
output_path = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/chromBPnet_training/outputs/pbmc_merged/chrombpnet_model_b1.0/contribution_scores_bw/averaged_scores/averaged_folds_pbmc-merged.profile_scores.h5"
# !sbatch $bash/average_contribution_scores_h5.sh $file_pattern $output_path
