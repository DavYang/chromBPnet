# %% [markdown]
# ### Date: 8/12/2025
#
# This notebook is used to call peaks using the filtered bams that only contain reads mapped to autosomes. I will call peaks using MACS3, which is availble using  "conda activate macs3". I will also use bedtools to filter the peaks against the hg38 blacklist.

# %%
# Call peaks for each sample using MACS3
# sample: cd14_monocyte_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/cd14_monocyte_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103618

# %%
# Call peaks for each sample using MACS3
# sample: cd19_cd20_b_cell_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/cd19_cd20_b_cell_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103624

# %%
# Call peaks for each sample using MACS3
# sample: cd4_t_cell_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/cd4_t_cell_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103625

# %%
# Call peaks for each sample using MACS3
# sample: cd8_t_cell_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/cd8_t_cell_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103627

# %%
# Call peaks for each sample using MACS3
# sample: neutrophil-1_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/neutrophil-1_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103628

# %%
# Call peaks for each sample using MACS3
# sample: neutrophil-2_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/neutrophil-2_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103629

# %%
# Call peaks for each sample using MACS3
# sample: neutrophil-3_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/neutrophil-3_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103630

# %%
# Call peaks for each sample using MACS3
# sample: nk_cell_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/nk_cell_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103631

# %%
# Call peaks for each sample using MACS3
# sample: pbmc-1_merged

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/pbmc-1_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14103632

# %%
# Call peaks for each sample using MACS3
# sample: pbmc-2

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/pbmc-2_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14206718

# %%
# Call peaks for each sample using MACS3
# sample: pbmc-3

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/pbmc-3_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14206724

# %%
# Call peaks for each sample using MACS3
# sample: pbmc-4

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_replicates/pbmc-4_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14206731

# %%
# Call peaks for each sample using MACS3
# sample: pbmc-2_4_merged (this sample is 3 separate samples from the same source paper, merged together to increase coverage)

import os

bash = "/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/bash"

IN_BAM="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/nf-core_atac/results/bwa/merged_library/autosomes_only/merged_pbmcs_2-4/pbmc-2_4_merged.mLb.clN.sorted.bam"
OUT_DIR="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/outputs"
BLACKLIST_FILE="/gs/gsfs0/shared-lab/greally-lab/David/chromBPnet_analysis/peak_calling/dependency_files/hg38-blacklist.v2.bed.gz"

# !sbatch $bash/call_peaks_MACS3.sh $IN_BAM $OUT_DIR $BLACKLIST_FILE
# Out:
# Submitted batch job 14215527
